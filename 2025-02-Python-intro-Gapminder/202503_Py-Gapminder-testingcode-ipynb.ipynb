# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data_europe = pd.read_csv('/Users/m.wehrens/Desktop/python_course/data/gapminder_gdp_europe.csv', index_col='country')
data_europe_transposed = data_europe.T

data_europe_transposed['min'] = data_europe_transposed.min(axis=1)
data_europe_transposed['max'] = data_europe_transposed.max(axis=1)
data_europe_transposed['year'] = data_europe_transposed.index

sns.lineplot(data_europe_transposed, x='year', y='min')
sns.lineplot(data_europe_transposed, x='year', y='max')
plt.legend(loc='best')
plt.xticks(rotation=90)

#
# Out:
# gdpPercap_1952    gdpPercap_1952
# gdpPercap_1957    gdpPercap_1957
# gdpPercap_1962    gdpPercap_1962
# gdpPercap_1967    gdpPercap_1967
# gdpPercap_1972    gdpPercap_1972
# gdpPercap_1977    gdpPercap_1977
# gdpPercap_1982    gdpPercap_1982
# gdpPercap_1987    gdpPercap_1987
# gdpPercap_1992    gdpPercap_1992
# gdpPercap_1997    gdpPercap_1997
# gdpPercap_2002    gdpPercap_2002
# gdpPercap_2007    gdpPercap_2007
# Name: year, dtype: object

# %%
MYPATH='/Users/m.wehrens/Data_UVA/2024_teaching/2025-03-gapminder/'
data_all = pd.read_csv(MYPATH+'data/gapminder_all.csv', index_col='country')
data_all.plot(kind='scatter', x='gdpPercap_2007', y='lifeExp_2007',
              s=data_all['pop_2007']/1e6)

sns.scatterplot(data_all, x='gdpPercap_2007', y='lifeExp_2007', s=data_all['pop_2007']/1e6)

# in a later exercise
plt.text(data_all.loc['United States','gdpPercap_2007'], data_all.loc['United States','lifeExp_2007'], 'United States')
plt.text(data_all.loc['Netherlands','gdpPercap_2007'], data_all.loc['Netherlands','lifeExp_2007'], 'Netherlands')
# Out:
# Text(36797.93332, 79.762, 'Netherlands')
